# %%
from citipy import citipy
import json
import numpy as np
import pandas as pd
import time

from config import weather_api_key
from config import weather_api_key1

# %%
# Create a set of 2000 random latitude and longitude combinations.
num_locs = 2000

lats = np.random.uniform(low=-90.000, high=90.000, size=num_locs)
lngs = np.random.uniform(low=-180.000, high=180.000, size=num_locs)

lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create lists to store cities and countries.
cities = []

# Loop over the coordinates.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # Only append if it is a new city.
    if city not in cities:
        cities.append(city)
    
# Sanity checks:
print (f"Initial count of cities: {len(cities)}")
# Out:
# Initial count of cities: 761

# %%
# Base URL for the OpenWeather API call.
base_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key1

print("-------------------------------------------------------------------------------")
print(f"Beginning Data Retrieval: Will attempt to find weather data for {len(cities)} cities")
print("-------------------------------------------------------------------------------\n")

# Create an empty list to hold the weather data.
city_data = []

## WARNING! The code below will take several mins to run, as we will throttle the API requests
# to 60 per min. This is because openweatherAPI will otherwise block the account if the rate limit
# is exceeded.

# If throttling is not desired, simply comment out the line: time.sleep(sleep_time)


# Initialize variables to keep track of rate limiting.
start_time = int(time.time())
current_time = start_time

# Loop over all cities.
for i, city in enumerate(cities):

    # Log every 60th record. In addition, introduce a sleep for the next batch so
    # we do not exceed the rate limit of openweatherAPI.
    if i % 60 == 0:
        print (f"Retrieving data for record {i} | {city}")
        
        if i > 0:
            # Get current time.
            current_time = int(time.time())
        
            # If we have made 60 calls and 1 min hasn't passed, we will sleep here.
            if current_time - start_time < 60:
                sleep_time = 60 - (current_time - start_time)
                print (f"Introducting a sleep of {sleep_time} seconds!")
                time.sleep(sleep_time) # <------ COMMENT OUT THIS LINE IF THROTTLING IS NOT DESIRED.
        
            # Get the new start time.
            start_time = int(time.time())
        
    
    # Create endpoint URL with each city.
    city_url = base_url + "&q=" + city.replace(" ","+")
    
    try:
        city_weather = requests.get(city_url).json()
        
        # The code below was used to check openweatherAPI response. It is commented out now.
        # rsp = json.dumps(city_weather, indent=4)
        # print(rsp)
        
        # Parse out the needed data.
        lat = city_weather["coord"]["lat"]
        lng = city_weather["coord"]["lon"]
        max_temp = city_weather["main"]["temp_max"]
        humidity = city_weather["main"]["humidity"]
        clouds = city_weather["clouds"]["all"]
        wind = city_weather["wind"]["speed"]
        country = city_weather["sys"]["country"]
        desc = city_weather['weather'][0]['description']

        # Append the city information into city_data list.
        city_data.append({'City': city.title(),
                          'Lat': lat,
                          'Lng': lng,
                          'Max Temp': max_temp,
                          'Humidity': humidity,
                          'Cloudiness': clouds,
                          'Wind Speed': wind,
                          'Country': country,
                          'Current Description': desc})

    except Exception as e:
        print(f"Failed attempt to find city: {city}, openweather response: {city_weather['message']}")
        pass

print("\n-------------------------------------------------------------------------------")
print(f"Data Retrieval Complete: Number of cities with valid weather data: {len(city_data)}")
print("-------------------------------------------------------------------------------")
# Out:
# -------------------------------------------------------------------------------
# Beginning Data Retrieval: Will attempt to find weather data for 761 cities
# -------------------------------------------------------------------------------
#
# Retrieving data for record 0 | busselton
# Failed attempt to find city: barentsburg, openweather response: city not found
# Failed attempt to find city: taolanaro, openweather response: city not found
# Failed attempt to find city: yomitan, openweather response: city not found
# Failed attempt to find city: warqla, openweather response: city not found
# Failed attempt to find city: meyungs, openweather response: city not found
# Failed attempt to find city: saleaula, openweather response: city not found
# Retrieving data for record 60 | punta arenas
# Introducting a sleep of 49 seconds!
# Failed attempt to find city: tuggurt, openweather response: city not found
# Failed attempt to find city: grimari, openweather response: city not found
# Failed attempt to find city: karkaralinsk, openweather response: city not found
# Retrieving data for record 120 | piopio
# Introducting a sleep of 49 seconds!
# Failed attempt to find city: amderma, openweather response: city not found
# Failed attempt to find city: mys shmidta, openweather response: city not found
# Failed attempt to find city: illoqqortoormiut, openweather response: city not found
# Failed attempt to find city: tsihombe, openweather response: city not found
# Failed attempt to find city: urdzhar, openweather response: city not found
# Failed attempt to find city: vestbygda, openweather response: city not found
# Retrieving data for record 180 | pisco
# Introducting a sleep of 46 seconds!
# Failed attempt to find city: vaitupu, openweather response: city not found
# Failed attempt to find city: fort saint john, openweather response: city not found
# Failed attempt to find city: grand river south east, openweather response: city not found
# Failed attempt to find city: palabuhanratu, openweather response: city not found
# Retrieving data for record 240 | beaufort
# Introducting a sleep of 46 seconds!
# Failed attempt to find city: tapaua, openweather response: city not found
# Failed attempt to find city: umzimvubu, openweather response: city not found
# Failed attempt to find city: tumannyy, openweather response: city not found
# Failed attempt to find city: attawapiskat, openweather response: city not found
# Retrieving data for record 300 | kokoda
# Introducting a sleep of 41 seconds!
# Failed attempt to find city: rungata, openweather response: city not found
# Failed attempt to find city: samusu, openweather response: city not found
# Failed attempt to find city: belushya guba, openweather response: city not found
# Failed attempt to find city: halalo, openweather response: city not found
# Failed attempt to find city: ngukurr, openweather response: city not found
# Failed attempt to find city: nizhneyansk, openweather response: city not found
# Retrieving data for record 360 | gazli
# Introducting a sleep of 47 seconds!
# Failed attempt to find city: lolua, openweather response: city not found
# Failed attempt to find city: kamenskoye, openweather response: city not found
# Failed attempt to find city: sentyabrskiy, openweather response: city not found
# Failed attempt to find city: tsienyane, openweather response: city not found
# Retrieving data for record 420 | dolores
# Introducting a sleep of 46 seconds!
# Failed attempt to find city: grand centre, openweather response: city not found
# Failed attempt to find city: yeletskiy, openweather response: city not found
# Failed attempt to find city: viligili, openweather response: city not found
# Failed attempt to find city: rawannawi, openweather response: city not found
# Failed attempt to find city: tidore, openweather response: city not found
# Retrieving data for record 480 | tasbuget
# Introducting a sleep of 47 seconds!
# Failed attempt to find city: tasbuget, openweather response: city not found
# Failed attempt to find city: hunza, openweather response: city not found
# Failed attempt to find city: samalaeulu, openweather response: city not found
# Failed attempt to find city: ituni, openweather response: city not found
# Failed attempt to find city: marcona, openweather response: city not found
# Failed attempt to find city: utiroa, openweather response: city not found
# Retrieving data for record 540 | pelotas
# Introducting a sleep of 43 seconds!
# Failed attempt to find city: teneguiban, openweather response: city not found
# Failed attempt to find city: sorvag, openweather response: city not found
# Failed attempt to find city: paradwip, openweather response: city not found
# Failed attempt to find city: bolungarvik, openweather response: city not found
# Failed attempt to find city: keshan, openweather response: city not found
# Failed attempt to find city: mrirt, openweather response: city not found
# Failed attempt to find city: satitoa, openweather response: city not found
# Retrieving data for record 600 | coahuayana
# Introducting a sleep of 40 seconds!
# Failed attempt to find city: toliary, openweather response: city not found
# Failed attempt to find city: mahaicony, openweather response: city not found
# Failed attempt to find city: inderborskiy, openweather response: city not found
# Failed attempt to find city: bargal, openweather response: city not found
# Retrieving data for record 660 | anchorage
# Introducting a sleep of 45 seconds!
# Failed attempt to find city: kuche, openweather response: city not found
# Failed attempt to find city: krasnoyarsk-45, openweather response: city not found
# Failed attempt to find city: duz, openweather response: city not found
# Retrieving data for record 720 | okha
# Introducting a sleep of 45 seconds!
# Failed attempt to find city: gurskoye, openweather response: city not found
# Failed attempt to find city: ijaki, openweather response: city not found
#
# -------------------------------------------------------------------------------
# Data Retrieval Complete: Number of cities with valid weather data: 701
# -------------------------------------------------------------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)

column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 
                'Cloudiness', 'Wind Speed', 'Current Description']

city_data_df = city_data_df[column_order]
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Busselton      AU -33.6500  115.3333     55.09        82          90
# 1  Puerto Ayora      EC  -0.7393  -90.3518     78.76        88          56
# 2     Upernavik      GL  72.7868  -56.1549     31.21        94          94
# 3        Atuona      PF  -9.8000 -139.0333     78.66        71          14
# 4        Tiarei      PF -17.5333 -149.3333     75.22        77          43
#
#    Wind Speed Current Description
# 0        8.19     overcast clouds
# 1        5.99       broken clouds
# 2       16.31     overcast clouds
# 3       11.01          few clouds
# 4       12.33          light rain

# %%
import os

# Save to CSV.
output_data_file = os.path.join('Weather_Database', 'WeatherPy_Database.csv')
city_data_df.to_csv(output_data_file, index_label="City_ID")
